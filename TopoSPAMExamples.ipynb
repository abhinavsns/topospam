# %% [markdown]
# # TopoSPAM - Topological Simulation Platform for Active Matter
# TopoSpam is a collection of software suite released under GPL 3.0 License for numerical simulation of active matter. It includes....

# %%
import TopoSpam

# %%
# %matplotlib inline

# %% [markdown]
# ## Two Dimenstional Active Fluid with Polar Order
#
# We solve the Ericksen-Leslie hydrodynamic model with periodic boundary conditions

# %%
#Setting Parameters for the simulation
#Params = TopoSpam.ActiveFluidParameters()
Params = TopoSpam.ActiveFluidParameters()

# %%
Params.Gd_Sz=17
Params.Ks=1.0
Params.Kb=1.0
Params.dmu=0.0
Params.nu=0.0
Params.zeta=1.0
Params.lamda=1.0
Params.eta=1.0
Params.gama=1.0
Params.tf=10
Params.dt=1e-2
Params.wrat=1
Params.Vtol=1e-2
Params.ttol=1e-4

# %% [markdown]
# We create the initial conditions

# %%
TopoSpam.InitializeActiveFluid()

# %%
Steps=TopoSpam.RunActiveFluidSimulation(Params,4)
# Out:
# Total number of Time steps taken by the adaptive stepper: 44
#
# The simulation took 1.386204(CPU) ------ 1.5373323029999999(Wall) Seconds.

# %%
Plot=TopoSpam.VizualizeIteration(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bx/gm6kthps2590x1f90y9sf52r0000gp/T/ipykernel_97712/4006588741.py in <module>
# ----> 1 Plot=TopoSpam.VizualizeIteration(0)
#
# NameError: name 'TopoSpam' is not defined

# %%
Plot=TopoSpam.VizualizeIteration(10)

# %%
TopoSpam.VizualizeAnimate(Steps)
# Out:
# <video width="1000" height="400" controls autoplay loop>
#   <source type="video/mp4" src="...
