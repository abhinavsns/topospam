# %%
#auto reload
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

import TopoSPAM.SpringLattice as sl
# load geometry

#initialize instance
Params = sl.SpringLatticeParameters()

#set parameters
Params.mesh_geometry = "flat-square"
Params.thickness = 0.1

#load mesh
Params.load_mesh()

#load spontaneous strain pattern
Params.nematic_coordinates = "zig_zag"
Params.load_strain_pattern(theta_o = 0.2, lambda1 = 1.25, lambda2 = 1.25**(-0.5))

#visualize the pattern
Params.visualize(mode = "discrete")

#run the simulation
#Steps=TopoSpam.RunSpringLatticeSimulationWithProgress(Params)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
